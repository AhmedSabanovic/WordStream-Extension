# %% [markdown]
# # Import Required Libraries

# %%
# pip install spacy

# %%
# python -m spacy download en_core_web_sm

# %%
import pandas as pd
import spacy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
# Initialize the SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # Load Dataset

# %%
# Load the sentimentdataset.csv file into a pandas DataFrame
df = pd.read_csv('CNN_Editors.tsv', delimiter='\t')
df.head()
# Out:
#    Year                                        Description Conference  \
# 0  2022  Here's a look at how the pandemic reshaped peo...   business
# 1  2022  March Madness isn't just for college basketbal...   business
# 2  2022  As crude prices surge, oil companies are rakin...   business
# 3  2022  Governments around the world must consider dra...   business
# 4  2022  The convenience of digital payments to both co...   business
#
#                                                Title  \
# 0  Two years later, remote work has changed milli...
# 1          Why March is so volatile for stocks - CNN
# 2  Stocks week ahead: Big Oil rakes in billions a...
# 3  Oil 'emergency': Work from home and drive slow...
# 4  Opinion: Technology is transforming the nature...
#
#                                         Author Names
# 0                                      Kathryn Vasel
# 1                       Paul R. La Monica,  Business
# 2                           Chris Isidore,  Business
# 3                               Matt Egan,  Business
# 4  As told to by Chris Wellisz, International Mon...

# %% [markdown]
# # Preprocess dataset

# %%
# Remove the 'Author Names' column
df.drop(columns=['Author Names'], inplace=True)
df.head()
# Out:
#    Year                                        Description Conference  \
# 0  2022  Here's a look at how the pandemic reshaped peo...   business
# 1  2022  March Madness isn't just for college basketbal...   business
# 2  2022  As crude prices surge, oil companies are rakin...   business
# 3  2022  Governments around the world must consider dra...   business
# 4  2022  The convenience of digital payments to both co...   business
#
#                                                Title
# 0  Two years later, remote work has changed milli...
# 1          Why March is so volatile for stocks - CNN
# 2  Stocks week ahead: Big Oil rakes in billions a...
# 3  Oil 'emergency': Work from home and drive slow...
# 4  Opinion: Technology is transforming the nature...

# %% [markdown]
# ## Exctract named entities

# %%
def extract_entities(text):
    doc = nlp(text)
    return ';'.join([ent.text for ent in doc.ents])

# Apply the function to the 'Description' column
df['Author Names'] = df['Description'].apply(extract_entities)
df.head()
# Out:
#    Year                                        Description Conference  \
# 0  2022  Here's a look at how the pandemic reshaped peo...   business
# 1  2022  March Madness isn't just for college basketbal...   business
# 2  2022  As crude prices surge, oil companies are rakin...   business
# 3  2022  Governments around the world must consider dra...   business
# 4  2022  The convenience of digital payments to both co...   business
#
#                                                Title  \
# 0  Two years later, remote work has changed milli...
# 1          Why March is so volatile for stocks - CNN
# 2  Stocks week ahead: Big Oil rakes in billions a...
# 3  Oil 'emergency': Work from home and drive slow...
# 4  Opinion: Technology is transforming the nature...
#
#                                         Author Names
# 0
# 1                                   March;this March
# 2
# 3  Russia;Ukraine;the International Energy Agency...
# 4

# %%
# Count the number of rows that are empty or NaN in the 'Author Names' column
empty_or_nan_count = df['Author Names'].isna().sum() + df['Author Names'].eq('').sum()

# Count the number of rows that are not empty or NaN in the 'Author Names' column
non_empty_count = len(df) - empty_or_nan_count

print(f"Empty or NaN rows: {empty_or_nan_count}")
print(f"Non-empty rows: {non_empty_count}")
# Out:
# Empty or NaN rows: 1072
# Non-empty rows: 36871

# %%
# Remove all the rows that are empty in the 'Author Names' column
df = df[df['Author Names'].apply(lambda x: x != '')]
df.head()
# Out:
#    Year                                        Description Conference  \
# 1  2022  March Madness isn't just for college basketbal...   business
# 3  2022  Governments around the world must consider dra...   business
# 5  2022  Inflation is everywhere: grocery stores, gas s...   business
# 6  2022  Burger King is trying to suspend its operation...   business
# 7  2022  The White House spent much of Friday frustrate...   business
#
#                                                Title  \
# 1          Why March is so volatile for stocks - CNN
# 3  Oil 'emergency': Work from home and drive slow...
# 5  Inflation is everywhere. Except your cell phon...
# 6  Burger King partner 'refuses' to close 800 Rus...
# 7  White House 'appalled' at Axios over Ukraine a...
#
#                                         Author Names
# 1                                   March;this March
# 3  Russia;Ukraine;the International Energy Agency...
# 5                                                one
# 6                             Burger King;Russia;800
# 7               The White House;Friday;Axios;Ukraine

# %% [markdown]
# ## Sentiment analysis

# %%
# Function to calculate normalized sentiment score
def calculate_sentiment(text):
    sentiment = analyzer.polarity_scores(text)
    normalized_score = (sentiment['compound'] + 1) / 2  # Normalize to range [0, 1]
    return normalized_score

# Apply the function to the 'Description' column
df['Sentiment Score'] = df['Description'].apply(calculate_sentiment)
df.head()
# Out:
#    Year                                        Description Conference  \
# 1  2022  March Madness isn't just for college basketbal...   business
# 3  2022  Governments around the world must consider dra...   business
# 5  2022  Inflation is everywhere: grocery stores, gas s...   business
# 6  2022  Burger King is trying to suspend its operation...   business
# 7  2022  The White House spent much of Friday frustrate...   business
#
#                                                Title  \
# 1          Why March is so volatile for stocks - CNN
# 3  Oil 'emergency': Work from home and drive slow...
# 5  Inflation is everywhere. Except your cell phon...
# 6  Burger King partner 'refuses' to close 800 Rus...
# 7  White House 'appalled' at Axios over Ukraine a...
#
#                                         Author Names  Sentiment Score
# 1                                   March;this March          0.18755
# 3  Russia;Ukraine;the International Energy Agency...          0.15960
# 5                                                one          0.80620
# 6                             Burger King;Russia;800          0.11415
# 7               The White House;Friday;Axios;Ukraine          0.47420

# %%
# Function to categorize sentiment
def categorize_sentiment(score):
    if score < 0.4:
        return 'Negative'
    elif 0.4 <= score <= 0.6:
        return 'Neutral'
    else:
        return 'Positive'

# Apply the function to create a new column with sentiment labels
df['Sentiment'] = df['Sentiment Score'].apply(categorize_sentiment)
df.head()
# Out:
#    Year                                        Description Conference  \
# 1  2022  March Madness isn't just for college basketbal...   business
# 3  2022  Governments around the world must consider dra...   business
# 5  2022  Inflation is everywhere: grocery stores, gas s...   business
# 6  2022  Burger King is trying to suspend its operation...   business
# 7  2022  The White House spent much of Friday frustrate...   business
#
#                                                Title  \
# 1          Why March is so volatile for stocks - CNN
# 3  Oil 'emergency': Work from home and drive slow...
# 5  Inflation is everywhere. Except your cell phon...
# 6  Burger King partner 'refuses' to close 800 Rus...
# 7  White House 'appalled' at Axios over Ukraine a...
#
#                                         Author Names  Sentiment Score  \
# 1                                   March;this March          0.18755
# 3  Russia;Ukraine;the International Energy Agency...          0.15960
# 5                                                one          0.80620
# 6                             Burger King;Russia;800          0.11415
# 7               The White House;Friday;Axios;Ukraine          0.47420
#
#   Sentiment
# 1  Negative
# 3  Negative
# 5  Positive
# 6  Negative
# 7   Neutral

# %% [markdown]
# ## Split important words

# %%
# Split the 'Author Names' column into multiple columns
important_words_split = df['Author Names'].str.split(';', expand=True)

# Rename the new columns to Author Names1, Author Names2, Author Names3, ...
important_words_split.columns = [f'Author Names{i+1}' for i in range(important_words_split.shape[1])]

# Concatenate the original dataframe (without 'Author Names') with the new split columns
df = pd.concat([df.drop(columns=['Author Names']), important_words_split], axis=1)

# %%
df.head()
# Out:
#    Year                                        Description Conference  \
# 1  2022  March Madness isn't just for college basketbal...   business
# 3  2022  Governments around the world must consider dra...   business
# 5  2022  Inflation is everywhere: grocery stores, gas s...   business
# 6  2022  Burger King is trying to suspend its operation...   business
# 7  2022  The White House spent much of Friday frustrate...   business
#
#                                                Title  Sentiment Score  \
# 1          Why March is so volatile for stocks - CNN          0.18755
# 3  Oil 'emergency': Work from home and drive slow...          0.15960
# 5  Inflation is everywhere. Except your cell phon...          0.80620
# 6  Burger King partner 'refuses' to close 800 Rus...          0.11415
# 7  White House 'appalled' at Axios over Ukraine a...          0.47420
#
#   Sentiment    Author Names1 Author Names2                    Author Names3  \
# 1  Negative            March    this March                             None
# 3  Negative           Russia       Ukraine  the International Energy Agency
# 5  Positive              one          None                             None
# 6  Negative      Burger King        Russia                              800
# 7   Neutral  The White House        Friday                            Axios
#
#   Author Names4  ... Author Names6 Author Names7 Author Names8 Author Names9  \
# 1          None  ...          None          None          None          None
# 3        Friday  ...          None          None          None          None
# 5          None  ...          None          None          None          None
# 6          None  ...          None          None          None          None
# 7       Ukraine  ...          None          None          None          None
#
#   Author Names10 Author Names11 Author Names12 Author Names13 Author Names14  \
# 1           None           None           None           None           None
# 3           None           None           None           None           None
# 5           None           None           None           None           None
# 6           None           None           None           None           None
# 7           None           None           None           None           None
#
#   Author Names15
# 1           None
# 3           None
# 5           None
# 6           None
# 7           None
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Melt

# %%
# Melt the dataset so that each Author Names corresponds to each row
df_melted = df.melt(id_vars=[col for col in df.columns if not col.startswith('Author Names')],
                    value_vars=[col for col in df.columns if col.startswith('Author Names')],
                    var_name='Author Names Column', value_name='Author Names')

# Drop rows where 'Author Names' is NaN
df_melted = df_melted.dropna(subset=['Author Names'])
df_melted.head()
# Out:
#    Year                                        Description Conference  \
# 0  2022  March Madness isn't just for college basketbal...   business
# 1  2022  Governments around the world must consider dra...   business
# 2  2022  Inflation is everywhere: grocery stores, gas s...   business
# 3  2022  Burger King is trying to suspend its operation...   business
# 4  2022  The White House spent much of Friday frustrate...   business
#
#                                                Title  Sentiment Score  \
# 0          Why March is so volatile for stocks - CNN          0.18755
# 1  Oil 'emergency': Work from home and drive slow...          0.15960
# 2  Inflation is everywhere. Except your cell phon...          0.80620
# 3  Burger King partner 'refuses' to close 800 Rus...          0.11415
# 4  White House 'appalled' at Axios over Ukraine a...          0.47420
#
#   Sentiment Author Names Column     Author Names
# 0  Negative       Author Names1            March
# 1  Negative       Author Names1           Russia
# 2  Positive       Author Names1              one
# 3  Negative       Author Names1      Burger King
# 4   Neutral       Author Names1  The White House

# %%
# Drop the 'Description' and 'Author Names Column' columns
df_melted = df_melted.drop(columns=['Description', 'Author Names Column', 'Sentiment Score', 'Conference'])
df_melted.head()
# Out:
#    Year                                              Title Sentiment  \
# 0  2022          Why March is so volatile for stocks - CNN  Negative
# 1  2022  Oil 'emergency': Work from home and drive slow...  Negative
# 2  2022  Inflation is everywhere. Except your cell phon...  Positive
# 3  2022  Burger King partner 'refuses' to close 800 Rus...  Negative
# 4  2022  White House 'appalled' at Axios over Ukraine a...   Neutral
#
#       Author Names
# 0            March
# 1           Russia
# 2              one
# 3      Burger King
# 4  The White House

# %%
# Rename the column 'Sentiment' to 'Conference'
df_melted.rename(columns={'Sentiment': 'Conference'}, inplace=True)

# %%
df_melted.head()
# Out:
#    Year                                              Title Conference  \
# 0  2022          Why March is so volatile for stocks - CNN   Negative
# 1  2022  Oil 'emergency': Work from home and drive slow...   Negative
# 2  2022  Inflation is everywhere. Except your cell phon...   Positive
# 3  2022  Burger King partner 'refuses' to close 800 Rus...   Negative
# 4  2022  White House 'appalled' at Axios over Ukraine a...    Neutral
#
#       Author Names
# 0            March
# 1           Russia
# 2              one
# 3      Burger King
# 4  The White House

# %% [markdown]
# ## Agreggate

# %% [markdown]
# # Save Preprocessed dataset

# %%
# Export the DataFrame to a new .tsv file
df_melted.to_csv('CNN_Sentiment2.tsv', sep='\t', index=False)
