# %% [markdown]
# # Import Required Libraries

# %%
# pip install spacy

# %%
# python -m spacy download en_core_web_sm

# %%
import pandas as pd
import spacy

# %%
# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # Load Dataset

# %%
# Load the sentimentdataset.csv file into a pandas DataFrame
df = pd.read_csv('CNN_Articles_sentiment.tsv', delimiter='\t')
df.head()
# Out:
#                                                 text  frequency  sentiment  \
# 0  Bomb squads in Germany successfully defused on...          1    0.50000
# 1  College footballs topranked LSU Tigers defeate...          1    0.17570
# 2  Udinese have gone top of the Italian Serie A t...          1    0.60115
# 3  The Czech Republic have secured their first Fe...          1    0.87530
# 4  Cristiano Ronaldo scored a superb hattrick as ...          1    0.92595
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %% [markdown]
# # Preprocess dataset

# %% [markdown]
# ## Exctract named entities

# %%
# Function to extract named entities
def extract_entities(text):
    doc = nlp(text)
    return ', '.join([ent.text for ent in doc.ents])

# Apply the function to the 'text' column
df['important_words'] = df['text'].apply(extract_entities)

# %%
df.head(10)
# Out:
#                                                 text  frequency  sentiment  \
# 0  Bomb squads in Germany successfully defused on...          1    0.50000
# 1  College footballs topranked LSU Tigers defeate...          1    0.17570
# 2  Udinese have gone top of the Italian Serie A t...          1    0.60115
# 3  The Czech Republic have secured their first Fe...          1    0.87530
# 4  Cristiano Ronaldo scored a superb hattrick as ...          1    0.92595
# 5  Bayern Munich have moved five points clear at ...          1    0.76335
# 6  World number six Martin Kaymer carded a superb...          1    0.95590
# 7  Authorities have issued an arrest warrant for ...          1    0.27060
# 8  Third seed Roger Federer returned to winning w...          1    0.93600
# 9  Former Serb international midfielder Sinisa Mi...          1    0.27060
#
#    year                                    important_words
# 0  2011                               Germany, Sunday, two
# 1  2011                         LSU Tigers, Saturday night
# 2  2011  the Italian Serie, Lazio, Antonio Di Natale, S...
# 3  2011  first, Fed Cup, Lucie Hradecka, Kveta Peschke,...
# 4  2011  Cristiano Ronaldo, Real Madrid, Osasuna, the S...
# 5  2011  Bayern Munich, five, German, Bundesliga, Augsb...
# 6  2011  six, Martin Kaymer, the HSBC Champions, Shangh...
# 7  2011                  Dallas, Terrell Owens, last month
# 8  2011  Third, Roger Federer, a month, Japans, Swiss, ...
# 9  2011  Serb, Sinisa Mihajlovic, Serie A, Fiorentina, ...

# %% [markdown]
# ## Split important words

# %%
# Remove the 'text' and 'frequency' columns
df = df.drop(columns=['text', 'frequency'])

# Split the 'important_words' column into multiple columns
important_words_split = df['important_words'].str.split(',', expand=True)

# Rename the new columns to word1, word2, word3, ...
important_words_split.columns = [f'word{i+1}' for i in range(important_words_split.shape[1])]

# Concatenate the original dataframe (without 'text' and 'important_words') with the new split columns
df = pd.concat([df.drop(columns=['important_words']), important_words_split], axis=1)
# Out:
#    frequency  sentiment  year              word1            word2  \
# 0          1    0.50000  2011            Germany           Sunday
# 1          1    0.17570  2011         LSU Tigers   Saturday night
# 2          1    0.60115  2011  the Italian Serie            Lazio
# 3          1    0.87530  2011              first          Fed Cup
# 4          1    0.92595  2011  Cristiano Ronaldo      Real Madrid
#
#                 word3           word4    word5        word6             word7  \
# 0                 two            None     None         None              None
# 1                None            None     None         None              None
# 2   Antonio Di Natale           Siena   Sunday         None              None
# 3      Lucie Hradecka   Kveta Peschke   Russia       Moscow            Sunday
# 4             Osasuna     the Spanish    three   Barcelonas   Athletic Bilbao
#
#   word8 word9 word10 word11 word12 word13 word14 word15
# 0  None  None   None   None   None   None   None   None
# 1  None  None   None   None   None   None   None   None
# 2  None  None   None   None   None   None   None   None
# 3  None  None   None   None   None   None   None   None
# 4  None  None   None   None   None   None   None   None

# %%
df.head()
# Out:
#    sentiment  year              word1            word2               word3  \
# 0    0.50000  2011            Germany           Sunday                 two
# 1    0.17570  2011         LSU Tigers   Saturday night                None
# 2    0.60115  2011  the Italian Serie            Lazio   Antonio Di Natale
# 3    0.87530  2011              first          Fed Cup      Lucie Hradecka
# 4    0.92595  2011  Cristiano Ronaldo      Real Madrid             Osasuna
#
#             word4    word5        word6             word7 word8 word9 word10  \
# 0            None     None         None              None  None  None   None
# 1            None     None         None              None  None  None   None
# 2           Siena   Sunday         None              None  None  None   None
# 3   Kveta Peschke   Russia       Moscow            Sunday  None  None   None
# 4     the Spanish    three   Barcelonas   Athletic Bilbao  None  None   None
#
#   word11 word12 word13 word14 word15
# 0   None   None   None   None   None
# 1   None   None   None   None   None
# 2   None   None   None   None   None
# 3   None   None   None   None   None
# 4   None   None   None   None   None

# %% [markdown]
# ## Melt

# %%
# Melt the dataframe to have each row correspond to a single 'word'
melted_df = df.melt(id_vars=['sentiment', 'year'], value_vars=[col for col in df.columns if col.startswith('word')], var_name='word_num', value_name='word')

# Drop rows where 'word' is None
melted_df = melted_df.dropna(subset=['word'])

# Drop the 'word_num' column as it is no longer needed
melted_df = melted_df.drop(columns=['word_num'])
melted_df.head()
# Out:
#    sentiment  year               word
# 0    0.50000  2011            Germany
# 1    0.17570  2011         LSU Tigers
# 2    0.60115  2011  the Italian Serie
# 3    0.87530  2011              first
# 4    0.92595  2011  Cristiano Ronaldo

# %%
# Drop rows where 'word' is None or empty spaces
melted_df = melted_df.dropna(subset=['word'])
melted_df['word'] = melted_df['word'].str.strip()
melted_df = melted_df[melted_df['word'] != '']

# %%
# Create a new column 'source' with the value 'cnn' for all rows
melted_df['source'] = 'cnn'
melted_df.head()
# Out:
#    sentiment  year               word source
# 0    0.50000  2011            Germany    cnn
# 1    0.17570  2011         LSU Tigers    cnn
# 2    0.60115  2011  the Italian Serie    cnn
# 3    0.87530  2011              first    cnn
# 4    0.92595  2011  Cristiano Ronaldo    cnn

# %% [markdown]
# ## Agreggate

# %%
# # Aggregate by 'year' and 'word' and count the frequency
# aggregated_df = melted_df.groupby(['year', 'word']).size().reset_index(name='frequency')
# aggregated_df.head()
# Out:
#    year        word  frequency
# 0  2011                     15
# 1  2011  A year old          1
# 2  2011    AC Milan          9
# 3  2011         AIC          1
# 4  2011         ATP          1

# %%
# Aggregate by 'word' and 'year'
aggregated_df = melted_df.groupby(['word', 'year']).agg(
    frequency=('word', 'size'),
    sentiment=('sentiment', 'mean')
).reset_index()

# %%
aggregated_df.head(20)
# Out:
#                            word  year  frequency  sentiment
# 0                                2011         15   0.506300
# 1                                2012         57   0.520173
# 2                                2013         81   0.535538
# 3                                2014         58   0.446820
# 4                                2015        165   0.520139
# 5                                2016        136   0.525694
# 6                                2017         89   0.532804
# 7                                2018        124   0.511051
# 8                                2019        160   0.539537
# 9                                2020        179   0.506749
# 10                               2021        194   0.510394
# 11                               2022         84   0.518226
# 12                   A  million  2018          1   0.500000
# 13                   A  million  2021          1   0.253050
# 14  A Breeze of Hope Foundation  2018          1   0.898200
# 15             A European Court  2015          1   0.601150
# 16                A German Life  2017          1   0.159600
# 17        A Second U Foundation  2020          1   0.911250
# 18                        A day  2012          1   0.500000
# 19                        A day  2013          3   0.246033

# %%
# Create a new column 'source' with the value 'cnn' for all rows
aggregated_df['source'] = 'cnn'

# Rename the column 'word' to 'text'
aggregated_df = aggregated_df.rename(columns={'word': 'text'})

# Reorder the columns
aggregated_df = aggregated_df[['source', 'year', 'text', 'sentiment', 'frequency']]

# %%
# Drop rows where 'word' is None or empty spaces
aggregated_df = aggregated_df.dropna(subset=['text'])
aggregated_df = aggregated_df[aggregated_df['text'] != '']

# %%
aggregated_df.head(50)
# Out:
#    source  year                          text  sentiment  frequency
# 12    cnn  2018                    A  million   0.500000          1
# 13    cnn  2021                    A  million   0.253050          1
# 14    cnn  2018   A Breeze of Hope Foundation   0.898200          1
# 15    cnn  2015              A European Court   0.601150          1
# 16    cnn  2017                 A German Life   0.159600          1
# 17    cnn  2020         A Second U Foundation   0.911250          1
# 18    cnn  2012                         A day   0.500000          1
# 19    cnn  2013                         A day   0.246033          3
# 20    cnn  2014                         A day   0.268125          2
# 21    cnn  2015                         A day   0.420483          3
# 22    cnn  2016                         A day   0.244700          1
# 23    cnn  2017                         A day   0.128575          2
# 24    cnn  2018                         A day   0.315100          4
# 25    cnn  2021                         A day   0.669600          2
# 26    cnn  2022                         A day   0.367925          2
# 27    cnn  2013                   A day later   0.613150          1
# 28    cnn  2015                      A decade   0.500000          1
# 29    cnn  2019                      A decade   0.627225          2
# 30    cnn  2020                A decade later   0.214050          1
# 31    cnn  2020                    A few days   0.398850          1
# 32    cnn  2016              A few days later   0.352000          1
# 33    cnn  2019                   A few hours   0.940600          1
# 34    cnn  2017             A few hours later   0.308400          1
# 35    cnn  2018                 A few hundred   0.149850          1
# 36    cnn  2013              A few kilometers   0.680600          1
# 37    cnn  2022              A few months ago   0.500000          1
# 38    cnn  2012                A few thousand   0.613150          1
# 39    cnn  2013                A few thousand   0.751150          1
# 40    cnn  2013               A few years ago   0.500000          1
# 41    cnn  2016               A few years ago   0.500000          1
# 42    cnn  2021               A few years ago   0.500000          1
# 43    cnn  2020     A little over three weeks   0.763350          1
# 44    cnn  2015  A little under two years ago   0.799700          1
# 45    cnn  2022                        A mile   0.309100          1
# 46    cnn  2019          A million US million   0.363400          1
# 47    cnn  2013                      A minute   0.500000          1
# 48    cnn  2014                       A month   0.053300          1
# 49    cnn  2016                       A month   0.346600          2
# 50    cnn  2022                       A month   0.394500          2
# 51    cnn  2012                A national day   0.052150          1
# 52    cnn  2019                  A pound foot   0.253050          1
# 53    cnn  2019                     A quarter   0.264850          1
# 54    cnn  2019                  A season ago   0.642300          1
# 55    cnn  2013                        A week   0.670000          1
# 56    cnn  2014                        A week   0.340900          1
# 57    cnn  2015                        A week   0.086450          1
# 58    cnn  2016                        A week   0.763350          1
# 59    cnn  2017                        A week   0.601150          1
# 60    cnn  2018                        A week   0.531375          2
# 61    cnn  2019                        A week   0.362800          2

# %% [markdown]
# # Save Preprocessed dataset

# %%
# Export the DataFrame to a new .tsv file
aggregated_df.to_csv('CNN_sentiment.tsv', sep='\t', index=False)

# %%
# Print the rows with the 10 largest values of 'frequency'
print(aggregated_df.nlargest(10, 'frequency'))
# Out:
#       source  year       text  sentiment  frequency
# 6937     cnn  2021      Covid   0.504336        394
# 31655    cnn  2022    Ukraine   0.376770        391
# 35185    cnn  2021      first   0.553638        379
# 31460    cnn  2021         US   0.441416        361
# 25710    cnn  2022    Russian   0.408030        309
# 31461    cnn  2022         US   0.435581        306
# 32690    cnn  2021  Wednesday   0.435256        301
# 35183    cnn  2019      first   0.585516        280
# 28567    cnn  2021     Sunday   0.520219        274
# 30444    cnn  2021   Thursday   0.424573        266

# %%
# Print all rows with 'text' equal to 'Ukraine' in order by year
ukraine_rows = aggregated_df[aggregated_df['text'] == 'Ukraine'].sort_values(by='year')
print(ukraine_rows)
# Out:
#       source  year     text  sentiment  frequency
# 31644    cnn  2011  Ukraine   0.672171          7
# 31645    cnn  2012  Ukraine   0.415269         21
# 31646    cnn  2013  Ukraine   0.531460          5
# 31647    cnn  2014  Ukraine   0.367803        173
# 31648    cnn  2015  Ukraine   0.353852         48
# 31649    cnn  2016  Ukraine   0.444290         10
# 31650    cnn  2017  Ukraine   0.238368         11
# 31651    cnn  2018  Ukraine   0.233319          8
# 31652    cnn  2019  Ukraine   0.398802         21
# 31653    cnn  2020  Ukraine   0.538190          5
# 31654    cnn  2021  Ukraine   0.394085         13
# 31655    cnn  2022  Ukraine   0.376770        391
