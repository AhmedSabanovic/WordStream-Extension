# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import spacy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from spacy.lang.en.stop_words import STOP_WORDS
import string

# %%
nlp = spacy.load("en_core_web_sm")

# %%
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # Load Dataset

# %%
# Load the sentimentdataset.csv file into a pandas DataFrame
df = pd.read_csv('True.csv')
df.head()
# Out:
#                                                title  \
# 0  Cambodian PM pulls back on threat to shut righ...
# 1  UK court agrees to extradite suspect in Italy ...
# 2  U.S. asks Venezuela for access to detained Cit...
# 3  U.S. to unveil revised self-driving car guidel...
# 4  Court allows Democratic states to defend Obama...
#
#                                                 text       subject  \
# 0  PHNOM PENH (Reuters) - Cambodian Prime Ministe...     worldnews
# 1  LONDON (Reuters) - A man accused of being part...     worldnews
# 2  CARACAS (Reuters) - Washington has asked the g...     worldnews
# 3  WASHINGTON (Reuters) - President Donald Trump’...  politicsNews
# 4  WASHINGTON (Reuters) - A U.S. appeals court on...  politicsNews
#
#                   date
# 0    December 2, 2017
# 1  September 29, 2017
# 2   November 23, 2017
# 3   September 5, 2017
# 4      August 1, 2017

# %% [markdown]
# # Preprocess dataset

# %%
# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Create a new column 'Year' that extracts the year from the 'date' column
df['Year'] = df['date'].dt.year
df.head()
# Out:
#                                                title  \
# 0  Cambodian PM pulls back on threat to shut righ...
# 1  UK court agrees to extradite suspect in Italy ...
# 2  U.S. asks Venezuela for access to detained Cit...
# 3  U.S. to unveil revised self-driving car guidel...
# 4  Court allows Democratic states to defend Obama...
#
#                                                 text       subject       date  \
# 0  PHNOM PENH (Reuters) - Cambodian Prime Ministe...     worldnews 2017-12-02
# 1  LONDON (Reuters) - A man accused of being part...     worldnews 2017-09-29
# 2  CARACAS (Reuters) - Washington has asked the g...     worldnews 2017-11-23
# 3  WASHINGTON (Reuters) - President Donald Trump’...  politicsNews 2017-09-05
# 4  WASHINGTON (Reuters) - A U.S. appeals court on...  politicsNews 2017-08-01
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
# Print the different values in the 'subject' column and their frequency
subject_counts = df['subject'].value_counts()
print(subject_counts)
# Out:
# subject
# politicsNews    5307
# worldnews       4693
# Name: count, dtype: int64

# %%
# Function to extract important words from text
def extract_important_words(text):
    doc = nlp(text)
    important_words = [token.text for token in doc if token.pos_ in ['NOUN', 'VERB', 'ADJ']]
    return ';'.join(important_words)

# Apply the function to the 'text' column
df['important_words'] = df['text'].apply(extract_important_words)
df.head()
# Out:
#                                                title  \
# 0  Cambodian PM pulls back on threat to shut righ...
# 1  UK court agrees to extradite suspect in Italy ...
# 2  U.S. asks Venezuela for access to detained Cit...
# 3  U.S. to unveil revised self-driving car guidel...
# 4  Court allows Democratic states to defend Obama...
#
#                                                 text       subject       date  \
# 0  PHNOM PENH (Reuters) - Cambodian Prime Ministe...     worldnews 2017-12-02
# 1  LONDON (Reuters) - A man accused of being part...     worldnews 2017-09-29
# 2  CARACAS (Reuters) - Washington has asked the g...     worldnews 2017-11-23
# 3  WASHINGTON (Reuters) - President Donald Trump’...  politicsNews 2017-09-05
# 4  WASHINGTON (Reuters) - A U.S. appeals court on...  politicsNews 2017-08-01
#
#    Year                                    important_words
# 0  2017  Cambodian;pulled;threat;close;human;rights;gro...
# 1  2017  man;accused;part;plot;kidnap;British;model;ext...
# 2  2017  asked;government;leftist;access;Venezuelan;Ame...
# 3  2017  administration;set;unveil;revised;self;driving...
# 4  2017  appeals;court;allowed;Democratic;state;attorne...

# %%
# Function to calculate normalized sentiment score
def calculate_sentiment(text):
    sentiment = analyzer.polarity_scores(text)
    normalized_score = (sentiment['compound'] + 1) / 2  # Normalize to range [0, 1]
    return normalized_score

# Apply the function to the 'text' column
df['sentiment_score'] = df['text'].apply(calculate_sentiment)
df.head()
# Out:
#                                                title  \
# 0  Cambodian PM pulls back on threat to shut righ...
# 1  UK court agrees to extradite suspect in Italy ...
# 2  U.S. asks Venezuela for access to detained Cit...
# 3  U.S. to unveil revised self-driving car guidel...
# 4  Court allows Democratic states to defend Obama...
#
#                                                 text       subject       date  \
# 0  PHNOM PENH (Reuters) - Cambodian Prime Ministe...     worldnews 2017-12-02
# 1  LONDON (Reuters) - A man accused of being part...     worldnews 2017-09-29
# 2  CARACAS (Reuters) - Washington has asked the g...     worldnews 2017-11-23
# 3  WASHINGTON (Reuters) - President Donald Trump’...  politicsNews 2017-09-05
# 4  WASHINGTON (Reuters) - A U.S. appeals court on...  politicsNews 2017-08-01
#
#    Year                                    important_words  sentiment_score
# 0  2017  Cambodian;pulled;threat;close;human;rights;gro...          0.99040
# 1  2017  man;accused;part;plot;kidnap;British;model;ext...          0.06300
# 2  2017  asked;government;leftist;access;Venezuelan;Ame...          0.00585
# 3  2017  administration;set;unveil;revised;self;driving...          0.92610
# 4  2017  appeals;court;allowed;Democratic;state;attorne...          0.08760

# %%
# Function to classify sentiment
def classify_sentiment(score):
    if score < 0.4:
        return 'Negative'
    elif 0.4 <= score <= 0.6:
        return 'Neutral'
    else:
        return 'Positive'

# Apply the function to the 'sentiment_score' column
df['sentiment'] = df['sentiment_score'].apply(classify_sentiment)
df.head()
# Out:
#                                                title  \
# 0  Cambodian PM pulls back on threat to shut righ...
# 1  UK court agrees to extradite suspect in Italy ...
# 2  U.S. asks Venezuela for access to detained Cit...
# 3  U.S. to unveil revised self-driving car guidel...
# 4  Court allows Democratic states to defend Obama...
#
#                                                 text       subject       date  \
# 0  PHNOM PENH (Reuters) - Cambodian Prime Ministe...     worldnews 2017-12-02
# 1  LONDON (Reuters) - A man accused of being part...     worldnews 2017-09-29
# 2  CARACAS (Reuters) - Washington has asked the g...     worldnews 2017-11-23
# 3  WASHINGTON (Reuters) - President Donald Trump’...  politicsNews 2017-09-05
# 4  WASHINGTON (Reuters) - A U.S. appeals court on...  politicsNews 2017-08-01
#
#    Year                                    important_words  sentiment_score  \
# 0  2017  Cambodian;pulled;threat;close;human;rights;gro...          0.99040
# 1  2017  man;accused;part;plot;kidnap;British;model;ext...          0.06300
# 2  2017  asked;government;leftist;access;Venezuelan;Ame...          0.00585
# 3  2017  administration;set;unveil;revised;self;driving...          0.92610
# 4  2017  appeals;court;allowed;Democratic;state;attorne...          0.08760
#
#   sentiment
# 0  Positive
# 1  Negative
# 2  Negative
# 3  Positive
# 4  Negative

# %%
# Drop the specified columns
df = df.drop(columns=['text', 'date', 'subject', 'sentiment'])
df.head()
# Out:
#                                                title  Year  \
# 0  Cambodian PM pulls back on threat to shut righ...  2017
# 1  UK court agrees to extradite suspect in Italy ...  2017
# 2  U.S. asks Venezuela for access to detained Cit...  2017
# 3  U.S. to unveil revised self-driving car guidel...  2017
# 4  Court allows Democratic states to defend Obama...  2017
#
#                                      important_words  sentiment_score
# 0  Cambodian;pulled;threat;close;human;rights;gro...          0.99040
# 1  man;accused;part;plot;kidnap;British;model;ext...          0.06300
# 2  asked;government;leftist;access;Venezuelan;Ame...          0.00585
# 3  administration;set;unveil;revised;self;driving...          0.92610
# 4  appeals;court;allowed;Democratic;state;attorne...          0.08760

# %%
df1 = df

# %%
# Split the 'important_words' column into separate columns whenever ';' appears
important_words_split = df['important_words'].str.split(';', expand=True)

# Rename the columns to word1, word2, ..., wordn
important_words_split.columns = [f'word{i+1}' for i in range(important_words_split.shape[1])]

# Concatenate the original DataFrame with the new split columns
df = pd.concat([df.drop(columns=['important_words']), important_words_split], axis=1)
df.head()
# Out:
#                                                title  Year  sentiment_score  \
# 0  Cambodian PM pulls back on threat to shut righ...  2017          0.99040
# 1  UK court agrees to extradite suspect in Italy ...  2017          0.06300
# 2  U.S. asks Venezuela for access to detained Cit...  2017          0.00585
# 3  U.S. to unveil revised self-driving car guidel...  2017          0.92610
# 4  Court allows Democratic states to defend Obama...  2017          0.08760
#
#             word1       word2    word3       word4       word5      word6  \
# 0       Cambodian      pulled   threat       close       human     rights
# 1             man     accused     part        plot      kidnap    British
# 2           asked  government  leftist      access  Venezuelan   American
# 3  administration         set   unveil     revised        self    driving
# 4         appeals       court  allowed  Democratic       state  attorneys
#
#         word7  ... word1312 word1313 word1314 word1315 word1316 word1317  \
# 0       group  ...     None     None     None     None     None     None
# 1       model  ...     None     None     None     None     None     None
# 2  executives  ...     None     None     None     None     None     None
# 3     vehicle  ...     None     None     None     None     None     None
# 4     general  ...     None     None     None     None     None     None
#
#   word1318 word1319 word1320 word1321
# 0     None     None     None     None
# 1     None     None     None     None
# 2     None     None     None     None
# 3     None     None     None     None
# 4     None     None     None     None
#
# [5 rows x 1324 columns]

# %%
# Melt the dataset so that each row corresponds to a word
df_melted = df.melt(id_vars=[col for col in df.columns if not col.startswith('word')],
                    value_vars=[col for col in df.columns if col.startswith('word')],
                    var_name='word_number', value_name='word')

# Drop rows with NaN values in the 'word' column
df_melted = df_melted.dropna(subset=['word'])

# %%
df_melted.head()
# Out:
#                                                title  Year  sentiment_score  \
# 0  Cambodian PM pulls back on threat to shut righ...  2017          0.99040
# 1  UK court agrees to extradite suspect in Italy ...  2017          0.06300
# 2  U.S. asks Venezuela for access to detained Cit...  2017          0.00585
# 3  U.S. to unveil revised self-driving car guidel...  2017          0.92610
# 4  Court allows Democratic states to defend Obama...  2017          0.08760
#
#   word_number            word
# 0       word1       Cambodian
# 1       word1             man
# 2       word1           asked
# 3       word1  administration
# 4       word1         appeals

# %%
df_melted = df_melted.drop(columns=['word_number'])

# %%
# Aggregate each word by year
aggregated_df = df_melted.groupby(['Year', 'word']).agg(
    average_sentiment=('sentiment_score', 'mean'),
    frequency=('word', 'size')
).reset_index()
aggregated_df.head()
# Out:
#    Year          word  average_sentiment  frequency
# 0  2016  "RECOMMENDED           0.030050          1
# 1  2016             #           0.990925          2
# 2  2016             %           0.994500          1
# 3  2016             *           0.956217          3
# 4  2016             +           0.994500          1

# %%
aggregated_df1 = aggregated_df

# %%
# Function to check if a word is a stopword or a symbol
def is_valid_word(word):
    return word not in STOP_WORDS and word not in string.punctuation

# Filter out symbols and stopwords from the 'word' column
aggregated_df = aggregated_df[aggregated_df['word'].apply(is_valid_word)]

# Rename the columns
aggregated_df = aggregated_df.rename(columns={
    'Year': 'year',
    'word': 'text',
    'average_sentiment': 'sentiment'
})

# Create a new column 'source' with the string 'true' for all rows
aggregated_df['source'] = 'true'
aggregated_df.head()
# Out:
#    year          text  sentiment  frequency source
# 0  2016  "RECOMMENDED    0.03005          1   true
# 6  2016  -Elimination    0.99490          1   true
# 7  2016           -H.    0.99875          1   true
# 8  2016       -annual    0.99490          1   true
# 9  2016   -government    0.66520          1   true

# %%
# # Save the preprocessed DataFrame to a new CSV file
# Export the DataFrame to a new .tsv file
aggregated_df.to_csv('true_sentiment.tsv', sep='\t', index=False)

# %%
###

# %%
###

# %%
###

# %%
# Drop the columns 'text', 'date', and 'sentiment_score'
df = df.drop(columns=['text', 'date', 'sentiment_score'])
df.head()
# Out:
#                                                title       subject  Year  \
# 0  Cambodian PM pulls back on threat to shut righ...     worldnews  2017
# 1  UK court agrees to extradite suspect in Italy ...     worldnews  2017
# 2  U.S. asks Venezuela for access to detained Cit...     worldnews  2017
# 3  U.S. to unveil revised self-driving car guidel...  politicsNews  2017
# 4  Court allows Democratic states to defend Obama...  politicsNews  2017
#
#                                      important_words sentiment
# 0  Cambodian;pulled;threat;close;human;rights;gro...  Positive
# 1  man;accused;part;plot;kidnap;British;model;ext...  Negative
# 2  asked;government;leftist;access;Venezuelan;Ame...  Negative
# 3  administration;set;unveil;revised;self;driving...  Positive
# 4  appeals;court;allowed;Democratic;state;attorne...  Negative

# %%
# Split the 'important_words' column into separate columns whenever ';' appears
important_words_split = df['important_words'].str.split(';', expand=True)

# Rename the columns to word1, word2, ..., wordn
important_words_split.columns = [f'word{i+1}' for i in range(important_words_split.shape[1])]

# Concatenate the original DataFrame with the new split columns
df = pd.concat([df.drop(columns=['important_words']), important_words_split], axis=1)

# Display the first few rows to verify the changes
df.head()
# Out:
#                                                title       subject  Year  \
# 0  Cambodian PM pulls back on threat to shut righ...     worldnews  2017
# 1  UK court agrees to extradite suspect in Italy ...     worldnews  2017
# 2  U.S. asks Venezuela for access to detained Cit...     worldnews  2017
# 3  U.S. to unveil revised self-driving car guidel...  politicsNews  2017
# 4  Court allows Democratic states to defend Obama...  politicsNews  2017
#
#   sentiment           word1       word2    word3       word4       word5  \
# 0  Positive       Cambodian      pulled   threat       close       human
# 1  Negative             man     accused     part        plot      kidnap
# 2  Negative           asked  government  leftist      access  Venezuelan
# 3  Positive  administration         set   unveil     revised        self
# 4  Negative         appeals       court  allowed  Democratic       state
#
#        word6  ... word1312 word1313 word1314 word1315 word1316 word1317  \
# 0     rights  ...     None     None     None     None     None     None
# 1    British  ...     None     None     None     None     None     None
# 2   American  ...     None     None     None     None     None     None
# 3    driving  ...     None     None     None     None     None     None
# 4  attorneys  ...     None     None     None     None     None     None
#
#   word1318 word1319 word1320 word1321
# 0     None     None     None     None
# 1     None     None     None     None
# 2     None     None     None     None
# 3     None     None     None     None
# 4     None     None     None     None
#
# [5 rows x 1325 columns]

# %%
# Melt the dataset so that each row corresponds to a word
melted_df = pd.melt(df, id_vars=['title', 'subject', 'Year', 'sentiment'], 
                    value_vars=[col for col in df.columns if col.startswith('word')],
                    var_name='word_number', value_name='word')

# Drop rows where 'word' is None
melted_df = melted_df.dropna(subset=['word'])

# Display the first few rows to verify the changes
melted_df.head()
# Out:
#                                                title       subject  Year  \
# 0  Cambodian PM pulls back on threat to shut righ...     worldnews  2017
# 1  UK court agrees to extradite suspect in Italy ...     worldnews  2017
# 2  U.S. asks Venezuela for access to detained Cit...     worldnews  2017
# 3  U.S. to unveil revised self-driving car guidel...  politicsNews  2017
# 4  Court allows Democratic states to defend Obama...  politicsNews  2017
#
#   sentiment word_number            word
# 0  Positive       word1       Cambodian
# 1  Negative       word1             man
# 2  Negative       word1           asked
# 3  Positive       word1  administration
# 4  Negative       word1         appeals

# %%
# Rename columns
melted_df1 = melted_df.rename(columns={
    'title': 'Title',
    'subject': 'Conference',
    'word': 'Author Names'
})

# Drop the 'Hashtag_Type' column as it is no longer needed
melted_df1 = melted_df1.drop(columns=['sentiment', 'word_number'])
melted_df1.head()
# Out:
#                                                Title    Conference  Year  \
# 0  Cambodian PM pulls back on threat to shut righ...     worldnews  2017
# 1  UK court agrees to extradite suspect in Italy ...     worldnews  2017
# 2  U.S. asks Venezuela for access to detained Cit...     worldnews  2017
# 3  U.S. to unveil revised self-driving car guidel...  politicsNews  2017
# 4  Court allows Democratic states to defend Obama...  politicsNews  2017
#
#      Author Names
# 0       Cambodian
# 1             man
# 2           asked
# 3  administration
# 4         appeals

# %%
# # Save the preprocessed DataFrame to a new CSV file
# Export the DataFrame to a new .tsv file
melted_df1.to_csv('true_Keywords.tsv', sep='\t', index=False)

# %%
# Rename columns
melted_df2 = melted_df.rename(columns={
    'title': 'Title',
    'sentiment': 'Conference',
    'word': 'Author Names'
})

# Drop the 'Hashtag_Type' column as it is no longer needed
melted_df2 = melted_df2.drop(columns=['subject', 'word_number'])
melted_df2.head()
# Out:
#                                                Title  Year Conference  \
# 0  Cambodian PM pulls back on threat to shut righ...  2017   Positive
# 1  UK court agrees to extradite suspect in Italy ...  2017   Negative
# 2  U.S. asks Venezuela for access to detained Cit...  2017   Negative
# 3  U.S. to unveil revised self-driving car guidel...  2017   Positive
# 4  Court allows Democratic states to defend Obama...  2017   Negative
#
#      Author Names
# 0       Cambodian
# 1             man
# 2           asked
# 3  administration
# 4         appeals

# %%
# # Save the preprocessed DataFrame to a new CSV file
# Export the DataFrame to a new .tsv file
melted_df2.to_csv('true_Sentiments.tsv', sep='\t', index=False)

# %%
###

# %%
###

# %%
###

# %% [markdown]
# # Melt

# %% [markdown]
# # Save Preprocessed dataset

# %%
# Rename columns
df_melted2 = df_melted.rename(columns={
    'Text': 'Title',
    'Platform': 'Conference',
    'year': 'Year',
    'Hashtag': 'Author Names'
})

# Drop the 'Hashtag_Type' column as it is no longer needed
df_melted2 = df_melted2.drop(columns=['SentimentCategory'])

# Display the first few rows of the transformed DataFrame to verify the changes
df_melted2.head()
# Out:
#                                                Title   Conference  Year  \
# 0   Enjoying a beautiful day at the park!        ...    Twitter    2023
# 1   Traffic was terrible this morning.           ...    Twitter    2023
# 2   Just finished an amazing workout! 💪          ...   Instagram   2023
# 3   Excited about the upcoming weekend getaway!  ...    Facebook   2023
# 4   Trying out a new recipe for dinner tonight.  ...   Instagram   2023
#
#   Author Names
# 0       Nature
# 1      Traffic
# 2      Fitness
# 3       Travel
# 4      Cooking

# %%
# # Save the preprocessed DataFrame to a new CSV file
# Export the DataFrame to a new .tsv file
df_melted2.to_csv('SocialMedia.tsv', sep='\t', index=False)
